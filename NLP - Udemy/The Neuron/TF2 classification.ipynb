# %%
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import roc_auc_score, f1_score, confusion_matrix

from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam

# %%
np.random.seed(33)
tf.random.set_seed(33)

# %%
df = pd.read_csv(r'C:\Users\lmbmo\Documents\Personal\Tutorials and courses\Machine-Learning\dataset\AirlineTweets.csv')

# %%
df.head()
# Out:
#              tweet_id  ...               user_timezone
# 0  570306133677760513  ...  Eastern Time (US & Canada)
# 1  570301130888122368  ...  Pacific Time (US & Canada)
# 2  570301083672813571  ...  Central Time (US & Canada)
# 3  570301031407624196  ...  Pacific Time (US & Canada)
# 4  570300817074462722  ...  Pacific Time (US & Canada)
#
# [5 rows x 15 columns]

# %%
df =  df[['airline_sentiment','text']]

# %%
df['airline_sentiment'].hist();

# %%
df = df[df['airline_sentiment']!= 'neutral'].copy()

# %%
target_map = {'positive': 1, 'negative': 0}
df['target'] = df['airline_sentiment'].map(target_map)

# %%
df.head()
# Out:
#   airline_sentiment                                               text  target
# 1          positive  @VirginAmerica plus you've added commercials t...       1
# 3          negative  @VirginAmerica it's really aggressive to blast...       0
# 4          negative  @VirginAmerica and it's a really big bad thing...       0
# 5          negative  @VirginAmerica seriously would pay $30 a fligh...       0
# 6          positive  @VirginAmerica yes, nearly every time I fly VX...       1

# %%
df_train, df_test = train_test_split(df, random_state= 33)

# %%
vectorizer = TfidfVectorizer(max_features=2000)
X_train = vectorizer.fit_transform(df_train['text'])
X_test = vectorizer.transform(df_test['text'])

# %%
# data must not be a sparse matrix before passing into tensorflow
X_train = X_train.toarray()
X_test = X_test.toarray()

# %%
Y_train = df_train['target']
Y_test = df_test['target']

# %%
#input dimension
D = X_train.shape[1]

# %%
#build model
i = Input(shape = (D, ))
x = Dense(1)(i) #sigmoid included in loss

# %%
model = Model(i, x)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 2000)]            0
#
#  dense (Dense)               (None, 1)                 2001
#
# =================================================================
# Total params: 2,001
# Trainable params: 2,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    loss = BinaryCrossentropy(from_logits=True),
    optimizer = Adam(learning_rate = 0.01),
    metrics = ['accuracy']
)

# %%
r = model.fit(
    X_train, Y_train,
    validation_data = (X_test, Y_test),
    epochs = 40,
    batch_size = 128
)
# Out:
# Epoch 1/40
# 68/68 [==============================] - 1s 7ms/step - loss: 0.4982 - accuracy: 0.7957 - val_loss: 0.4108 - val_accuracy: 0.7938
# Epoch 2/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.3720 - accuracy: 0.7994 - val_loss: 0.3536 - val_accuracy: 0.8073
# Epoch 3/40
# 68/68 [==============================] - 0s 4ms/step - loss: 0.3189 - accuracy: 0.8210 - val_loss: 0.3154 - val_accuracy: 0.8306
# Epoch 4/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.2817 - accuracy: 0.8460 - val_loss: 0.2891 - val_accuracy: 0.8475
# Epoch 5/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.2543 - accuracy: 0.8656 - val_loss: 0.2701 - val_accuracy: 0.8617
# Epoch 6/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.2335 - accuracy: 0.8828 - val_loss: 0.2557 - val_accuracy: 0.8739
# Epoch 7/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.2170 - accuracy: 0.8967 - val_loss: 0.2448 - val_accuracy: 0.8843
# Epoch 8/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.2036 - accuracy: 0.9034 - val_loss: 0.2362 - val_accuracy: 0.8902
# Epoch 9/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1924 - accuracy: 0.9100 - val_loss: 0.2295 - val_accuracy: 0.8926
# Epoch 10/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1828 - accuracy: 0.9168 - val_loss: 0.2238 - val_accuracy: 0.8950
# Epoch 11/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1747 - accuracy: 0.9233 - val_loss: 0.2194 - val_accuracy: 0.8971
# Epoch 12/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1675 - accuracy: 0.9254 - val_loss: 0.2155 - val_accuracy: 0.8981
# Epoch 13/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1611 - accuracy: 0.9278 - val_loss: 0.2121 - val_accuracy: 0.9016
# Epoch 14/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1554 - accuracy: 0.9318 - val_loss: 0.2101 - val_accuracy: 0.9033
# Epoch 15/40
# 68/68 [==============================] - 0s 4ms/step - loss: 0.1502 - accuracy: 0.9338 - val_loss: 0.2078 - val_accuracy: 0.9044
# Epoch 16/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1456 - accuracy: 0.9377 - val_loss: 0.2056 - val_accuracy: 0.9051
# Epoch 17/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1413 - accuracy: 0.9404 - val_loss: 0.2042 - val_accuracy: 0.9061
# Epoch 18/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1374 - accuracy: 0.9422 - val_loss: 0.2032 - val_accuracy: 0.9064
# Epoch 19/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1337 - accuracy: 0.9436 - val_loss: 0.2017 - val_accuracy: 0.9064
# Epoch 20/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1304 - accuracy: 0.9464 - val_loss: 0.2014 - val_accuracy: 0.9071
# Epoch 21/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1273 - accuracy: 0.9471 - val_loss: 0.2008 - val_accuracy: 0.9068
# Epoch 22/40
# 68/68 [==============================] - 0s 4ms/step - loss: 0.1244 - accuracy: 0.9500 - val_loss: 0.2000 - val_accuracy: 0.9078
# Epoch 23/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1217 - accuracy: 0.9503 - val_loss: 0.1998 - val_accuracy: 0.9082
# Epoch 24/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1191 - accuracy: 0.9531 - val_loss: 0.1996 - val_accuracy: 0.9096
# Epoch 25/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1167 - accuracy: 0.9533 - val_loss: 0.1994 - val_accuracy: 0.9099
# Epoch 26/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1145 - accuracy: 0.9551 - val_loss: 0.2000 - val_accuracy: 0.9085
# Epoch 27/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1123 - accuracy: 0.9549 - val_loss: 0.1996 - val_accuracy: 0.9113
# Epoch 28/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1102 - accuracy: 0.9560 - val_loss: 0.1997 - val_accuracy: 0.9116
# Epoch 29/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1083 - accuracy: 0.9564 - val_loss: 0.2000 - val_accuracy: 0.9116
# Epoch 30/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1065 - accuracy: 0.9576 - val_loss: 0.2003 - val_accuracy: 0.9109
# Epoch 31/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1047 - accuracy: 0.9574 - val_loss: 0.2003 - val_accuracy: 0.9109
# Epoch 32/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1030 - accuracy: 0.9585 - val_loss: 0.2006 - val_accuracy: 0.9103
# Epoch 33/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.1014 - accuracy: 0.9592 - val_loss: 0.2014 - val_accuracy: 0.9099
# Epoch 34/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.0998 - accuracy: 0.9608 - val_loss: 0.2017 - val_accuracy: 0.9099
# Epoch 35/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.0984 - accuracy: 0.9600 - val_loss: 0.2018 - val_accuracy: 0.9113
# Epoch 36/40
# 68/68 [==============================] - 0s 4ms/step - loss: 0.0970 - accuracy: 0.9633 - val_loss: 0.2032 - val_accuracy: 0.9103
# Epoch 37/40
# 68/68 [==============================] - 0s 4ms/step - loss: 0.0955 - accuracy: 0.9623 - val_loss: 0.2034 - val_accuracy: 0.9106
# Epoch 38/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.0942 - accuracy: 0.9644 - val_loss: 0.2040 - val_accuracy: 0.9116
# Epoch 39/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.0929 - accuracy: 0.9657 - val_loss: 0.2049 - val_accuracy: 0.9113
# Epoch 40/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.0918 - accuracy: 0.9648 - val_loss: 0.2051 - val_accuracy: 0.9130

# %%
# Plot loss per iteration
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend();

# %%
# Plot accuracy per iteration
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend();

# %%
P_train = ((model.predict(X_train) > 0) * 1.0).flatten()
P_test = ((model.predict(X_test) > 0) * 1.0).flatten()
# Out:
# 271/271 [==============================] - 1s 2ms/step
# 91/91 [==============================] - 0s 1ms/step

# %%
cm = confusion_matrix(Y_train, P_train, normalize='true')
cm
# Out:
# array([[0.99114273, 0.00885727],
#        [0.08710407, 0.91289593]])

# %%
def plot_cm(cm):
    classes = ['negative', 'positive']
    df_cm = pd.DataFrame(cm, index=classes, columns=classes)
    ax = sns.heatmap(df_cm, annot=True, fmt='g')
    ax.set_xlabel("Predicted")
    ax.set_ylabel("Target")

plot_cm(cm)

# %%
cm_test = confusion_matrix(Y_test, P_test, normalize='true')
plot_cm(cm_test)

# %%
Pr_train = model.predict(X_train)
Pr_test = model.predict(X_test)
print("Train AUC:", roc_auc_score(Y_train, Pr_train))
print("Test AUC:", roc_auc_score(Y_test, Pr_test))
# Out:
# 271/271 [==============================] - 0s 2ms/step
# 91/91 [==============================] - 0s 1ms/step
# Train AUC: 0.9948810862093774
# Test AUC: 0.956295185031673

# %%
print("Train F1:", f1_score(Y_train, P_train))
print("Test F1:", f1_score(Y_test, P_test))
# Out:
# Train F1: 0.9375544583212315
# Test F1: 0.7779816513761468

# %%
model.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x21f15b6f460>,
#  <keras.layers.core.dense.Dense at 0x21f15b6d000>]

# %%
model.layers[1].get_weights()
# Out:
# [array([[-3.4336889],
#         [ 2.097316 ],
#         [-1.689024 ],
#         ...,
#         [ 1.1097178],
#         [ 1.1866271],
#         [-2.3652573]], dtype=float32),
#  array([-0.19231732], dtype=float32)]

# %%
w = model.layers[1].get_weights()[0]

# %%
word_index_map = vectorizer.vocabulary_
word_index_map
# Out:
# {'united': 1846,
#  'have': 855,
#  'talked': 1711,
#  'to': 1770,
#  'them': 1737,
#  'on': 1253,
#  'standby': 1651,
#  'for': 751,
#  'tomorrow': 1775,
#  'but': 285,
#  'it': 965,
#  'doesn': 559,
#  'look': 1065,
#  'good': 815,
#  'may': 1111,
#  'stay': 1661,
#  'here': 874,
#  'till': 1762,
#  'friday': 769,
#  'amp': 136,
#  'that': 1733,
#  'not': 1221,
#  'can': 299,
#  'we': 1912,
#  'get': 798,
#  'an': 137,
#  'explanation': 661,
#  'why': 1941,
#  'from': 774,
#  'houston': 901,
#  'has': 851,
#  'been': 231,
#  'delayed': 492,
#  'now': 1231,
#  're': 1424,
#  'hearing': 865,
#  'crew': 452,
#  'about': 68,
#  'cancelled': 300,
#  'flightlations': 729,
#  'usairways': 1866,
#  'hold': 883,
#  '23': 25,
#  'all': 118,
#  'because': 229,
#  'they': 1741,
#  'won': 1954,
#  'let': 1030,
#  'me': 1116,
#  'use': 1869,
#  'companion': 391,
#  'voucher': 1889,
#  'online': 1258,
#  'http': 907,
#  'co': 376,
#  'southwestair': 1635,
#  'my': 1191,
#  'flight': 722,
#  'was': 1901,
#  'flighted': 726,
#  'and': 138,
#  'times': 1765,
#  'are': 165,
#  'long': 1063,
#  'leg': 1025,
#  'with': 1950,
#  'you': 1993,
#  'americanair': 133,
#  'today': 1771,
#  'wait': 1892,
#  'of': 1238,
#  'unbelievable': 1836,
#  'days': 480,
#  'through': 1754,
#  'person': 1319,
#  'over': 1282,
#  'hours': 900,
#  'still': 1666,
#  'going': 811,
#  'tough': 1783,
#  'night': 1210,
#  'two': 1826,
#  '90': 64,
#  'minute': 1158,
#  'calls': 297,
#  'in': 931,
#  'phoenix': 1325,
#  'one': 1256,
#  'aircraft': 111,
#  'ready': 1428,
#  'acceptable': 75,
#  'well': 1923,
#  'showing': 1580,
#  'am': 129,
#  'sitting': 1595,
#  'at': 186,
#  'the': 1735,
#  'gate': 793,
#  'plane': 1342,
#  'departed': 503,
#  'virginamerica': 1886,
#  'started': 1655,
#  'using': 1873,
#  'overhead': 1284,
#  'bin': 245,
#  'then': 1738,
#  'offered': 1241,
#  'seated': 1535,
#  'next': 1207,
#  'jetblue': 975,
#  'did': 524,
#  'no': 1213,
#  'idea': 920,
#  'where': 1934,
#  'is': 960,
#  'worst': 1970,
#  'customer': 465,
#  'service': 1556,
#  'experience': 655,
#  'ever': 634,
#  '40': 44,
#  'minutes': 1159,
#  'jetway': 976,
#  'ewr': 639,
#  'tonight': 1776,
#  'disappointed': 541,
#  'seems': 1544,
#  'without': 1952,
#  'board': 254,
#  'us': 1864,
#  'any': 148,
#  'airlines': 113,
#  've': 1879,
#  'out': 1277,
#  'awful': 206,
#  'what': 1929,
#  'will': 1944,
#  'be': 225,
#  'sucks': 1680,
#  'fail': 670,
#  'would': 1973,
#  'hard': 849,
#  'worse': 1969,
#  'than': 1730,
#  'last': 1013,
#  'time': 1763,
#  'sure': 1690,
#  'll': 1054,
#  'give': 802,
#  'shot': 1574,
#  'quality': 1412,
#  'work': 1961,
#  'just': 982,
#  'flightled': 730,
#  'this': 1747,
#  'ridiculous': 1488,
#  'waiting': 1894,
#  'weight': 1921,
#  'info': 945,
#  'past': 1303,
#  '30': 35,
#  'being': 235,
#  'given': 803,
#  'callback': 294,
#  'option': 1263,
#  'turned': 1817,
#  'off': 1239,
#  'how': 902,
#  'accurate': 81,
#  'dept': 509,
#  'late': 1014,
#  'flightr': 733,
#  'hear': 863,
#  'same': 1518,
#  'curious': 461,
#  'reply': 1458,
#  'do': 557,
#  'check': 347,
#  'outlets': 1279,
#  'when': 1933,
#  'moved': 1181,
#  'different': 530,
#  'equipment': 622,
#  'after': 99,
#  'boarding': 256,
#  'due': 581,
#  'malfunction': 1101,
#  'oh': 1248,
#  'got': 817,
#  'right': 1489,
#  'agent': 103,
#  'kept': 987,
#  'didn': 525,
#  'fix': 716,
#  'problem': 1390,
#  'thank': 1731,
#  'left': 1024,
#  'ipad': 957,
#  'den': 499,
#  'claim': 360,
#  'so': 1615,
#  'many': 1107,
#  'memories': 1130,
#  'plz': 1356,
#  'help': 869,
#  'back': 209,
#  'flying': 745,
#  'or': 1265,
#  'air': 109,
#  'again': 101,
#  'changes': 335,
#  'flightations': 724,
#  'up': 1854,
#  'big': 243,
#  'unacceptable': 1834,
#  'wish': 1949,
#  'team': 1717,
#  'member': 1128,
#  'pick': 1329,
#  'phone': 1326,
#  'point': 1358,
#  'alone': 123,
#  'helpful': 871,
#  'example': 642,
#  'pay': 1308,
#  'hotel': 897,
#  'food': 750,
#  'alternate': 127,
#  'city': 359,
#  'clear': 366,
#  'record': 1440,
#  'except': 644,
#  'he': 858,
#  'stuck': 1675,
#  'runway': 1512,
#  'also': 126,
#  'promised': 1398,
#  'change': 333,
#  'wife': 1942,
#  'name': 1193,
#  'account': 79,
#  'done': 566,
#  'wtf': 1978,
#  'hi': 876,
#  'calling': 296,
#  'mins': 1156,
#  'frustrated': 776,
#  'thx': 1757,
#  'finding': 709,
#  'clt': 371,
#  'pvd': 1411,
#  'our': 1276,
#  'original': 1269,
#  'think': 1744,
#  'weeks': 1920,
#  'more': 1175,
#  'enough': 616,
#  'contact': 425,
#  'lose': 1069,
#  'customers': 466,
#  'having': 857,
#  'flights': 734,
#  'nashville': 1194,
#  'guys': 829,
#  'rock': 1492,
#  'your': 1995,
#  'site': 1594,
#  'trying': 1812,
#  'getting': 800,
#  'text': 1729,
#  'enter': 617,
#  'card': 307,
#  'top': 1779,
#  'priority': 1387,
#  'nothing': 1225,
#  'else': 601,
#  'even': 630,
#  'legroom': 1026,
#  'via': 1882,
#  '400': 45,
#  'reimbursement': 1450,
#  'unprofessional': 1851,
#  '21': 23,
#  'feb': 688,
#  'very': 1881,
#  'full': 783,
#  'complaint': 398,
#  'thanks': 1732,
#  'quick': 1416,
#  'response': 1479,
#  'appreciated': 164,
#  'mco': 1114,
#  'details': 519,
#  'leaving': 1023,
#  'hour': 899,
#  'mechanical': 1121,
#  'delay': 491,
#  'need': 1199,
#  'meals': 1118,
#  'st': 1648,
#  'who': 1937,
#  'see': 1541,
#  'broke': 271,
#  'baby': 208,
#  'checked': 348,
#  'told': 1774,
#  'her': 873,
#  'their': 1736,
#  'list': 1047,
#  'preferred': 1377,
#  'line': 1044,
#  'if': 921,
#  'could': 436,
#  'wanted': 1898,
#  'call': 293,
#  'wouldn': 1974,
#  'internet': 953,
#  'make': 1097,
#  'reservation': 1470,
#  'several': 1560,
#  'computers': 404,
#  'called': 295,
#  '12': 6,
#  'three': 1753,
#  'willing': 1945,
#  'missed': 1162,
#  'lax': 1016,
#  'chicago': 353,
#  'mess': 1135,
#  'better': 240,
#  'miss': 1161,
#  'able': 67,
#  'ord': 1266,
#  'home': 885,
#  'yet': 1990,
#  'there': 1739,
#  'error': 623,
#  'choice': 356,
#  'lost': 1071,
#  'yesterday': 1989,
#  'filled': 705,
#  'form': 757,
#  'catering': 317,
#  'go': 808,
#  'other': 1273,
#  'day': 479,
#  'charge': 339,
#  'double': 570,
#  'had': 831,
#  'ticket': 1758,
#  'prices': 1384,
#  'middle': 1144,
#  'truck': 1806,
#  'mobile': 1167,
#  'broken': 272,
#  'shows': 1581,
#  'number': 1232,
#  'points': 1359,
#  'checkin': 349,
#  'case': 315,
#  'found': 761,
#  'pathetic': 1304,
#  'wants': 1899,
#  '25': 28,
#  'seat': 1534,
#  'assignment': 183,
#  'sunday': 1684,
#  'weather': 1913,
#  'ok': 1249,
#  'monday': 1171,
#  'busy': 284,
#  'crazy': 449,
#  'some': 1619,
#  'delaying': 493,
#  'smh': 1609,
#  '99': 65,
#  'dca': 482,
#  'delays': 494,
#  'side': 1584,
#  'safety': 1516,
#  'inconvenience': 937,
#  'people': 1314,
#  'connecting': 418,
#  'replying': 1459,
#  'feel': 691,
#  'little': 1051,
#  'goes': 810,
#  'trust': 1810,
#  'future': 789,
#  'booking': 260,
#  'confirmed': 413,
#  'ticketed': 1759,
#  'purchased': 1408,
#  'fact': 669,
#  'totally': 1781,
#  'appreciate': 163,
#  'made': 1092,
#  'super': 1685,
#  'easy': 594,
#  'too': 1777,
#  'until': 1853,
#  'higher': 878,
#  'rate': 1421,
#  'loving': 1080,
#  'cost': 434,
#  'working': 1964,
#  'staff': 1649,
#  'as': 175,
#  'employee': 608,
#  'responsible': 1482,
#  'social': 1616,
#  'media': 1123,
#  'yes': 1988,
#  'probably': 1389,
#  'care': 308,
#  'however': 903,
#  'actions': 84,
#  'say': 1525,
#  'otherwise': 1275,
#  'luv': 1090,
#  'virgin': 1885,
#  'america': 131,
#  'should': 1575,
#  'free': 766,
#  'baggage': 215,
#  'email': 603,
#  'by': 289,
#  'aa': 66,
#  '500': 51,
#  'delta': 498,
#  'maybe': 1112,
#  'trip': 1802,
#  'claims': 361,
#  'thought': 1752,
#  'paid': 1290,
#  '50': 50,
#  'instead': 950,
#  'awesome': 205,
#  'rt': 1505,
#  'watch': 1906,
#  '35': 39,
#  '000': 1,
#  'feet': 695,
#  'oscars': 1272,
#  'open': 1261,
#  'great': 821,
#  'way': 1910,
#  'finish': 712,
#  '18': 15,
#  'arrival': 169,
#  'issue': 962,
#  'confirmation': 412,
#  'much': 1187,
#  'phl': 1323,
#  'while': 1936,
#  'flew': 721,
#  'reason': 1432,
#  'iah': 916,
#  'entertainment': 618,
#  'system': 1701,
#  'wifi': 1943,
#  'despite': 515,
#  'app': 158,
#  'please': 1351,
#  'something': 1623,
#  'speed': 1640,
#  'connections': 420,
#  'planes': 1343,
#  'might': 1146,
#  'non': 1215,
#  'existent': 650,
#  'always': 128,
#  'travel': 1791,
#  'doubt': 571,
#  'major': 1096,
#  'airline': 112,
#  'feedback': 690,
#  'booked': 259,
#  'take': 1705,
#  'note': 1223,
#  'actually': 86,
#  'making': 1099,
#  'extremely': 665,
#  'inconvenient': 938,
#  'situation': 1596,
#  'rude': 1506,
#  'says': 1527,
#  'try': 1811,
#  'agents': 104,
#  'tickets': 1760,
#  'paying': 1309,
#  'frustrating': 777,
#  'know': 996,
#  'dealing': 486,
#  'phlairport': 1324,
#  'hot': 896,
#  'pls': 1354,
#  'send': 1549,
#  'looks': 1068,
#  'like': 1041,
#  'connection': 419,
#  'treat': 1797,
#  'onboard': 1254,
#  'enjoy': 615,
#  'joke': 980,
#  'special': 1639,
#  'services': 1557,
#  '15': 11,
#  'ppl': 1374,
#  'deep': 488,
#  'talk': 1710,
#  'put': 1410,
#  'omg': 1252,
#  'bumped': 280,
#  'respond': 1476,
#  'everyone': 636,
#  'complaints': 399,
#  'mine': 1154,
#  'btw': 274,
#  'speaking': 1638,
#  'month': 1173,
#  'aviation': 200,
#  'shout': 1577,
#  'his': 881,
#  'twitter': 1825,
#  'company': 392,
#  'policy': 1362,
#  'refuses': 1447,
#  'employees': 609,
#  'speak': 1637,
#  'interesting': 951,
#  'new': 1204,
#  'club': 372,
#  'hare': 850,
#  'difficult': 531,
#  'already': 125,
#  'reflight': 1442,
#  'problems': 1391,
#  'cell': 323,
#  'notifications': 1228,
#  'received': 1438,
#  'miles': 1149,
#  'mileageplus': 1148,
#  '150': 12,
#  'dfw': 521,
#  'understand': 1840,
#  'im': 925,
#  'love': 1076,
#  'those': 1750,
#  'departure': 506,
#  'needs': 1201,
#  'car': 306,
#  'desks': 514,
#  'shame': 1563,
#  'apology': 157,
#  'unfortunately': 1842,
#  'bad': 211,
#  'experiences': 657,
#  'longer': 1064,
#  'southwest': 1634,
#  'anyone': 150,
#  'sad': 1513,
#  'afford': 98,
#  'trips': 1803,
#  'though': 1751,
#  'airport': 115,
#  'bag': 214,
#  'filed': 703,
#  'only': 1259,
#  'ground': 823,
#  'extended': 663,
#  'tried': 1801,
#  'handle': 836,
#  'guess': 827,
#  'wrong': 1977,
#  'sit': 1593,
#  'move': 1180,
#  'stuff': 1676,
#  'around': 168,
#  'needed': 1200,
#  'passenger': 1300,
#  'large': 1011,
#  'down': 572,
#  'part': 1295,
#  'nothappy': 1224,
#  'refund': 1443,
#  'far': 680,
#  'courtesy': 445,
#  'training': 1788,
#  'gonna': 814,
#  'mdw': 1115,
#  'stop': 1668,
#  'ur': 1863,
#  'bs': 273,
#  'anywhere': 153,
#  'starting': 1656,
#  'fly': 741,
#  '130': 8,
#  'place': 1338,
#  'thats': 1734,
#  'cle': 363,
#  'status': 1660,
#  'match': 1108,
#  'message': 1136,
#  'tell': 1721,
#  'went': 1924,
#  'absolutely': 71,
#  'life': 1039,
#  'hrs': 906,
#  'failed': 671,
#  'gates': 794,
#  'zero': 1999,
#  'communication': 389,
#  'flt': 739,
#  'scheduled': 1529,
#  'believe': 236,
#  'isn': 961,
#  'available': 199,
#  'bos': 261,
#  'gt': 825,
#  'sfo': 1562,
#  'shit': 1568,
#  'its': 969,
#  'half': 834,
#  'first': 713,
#  'class': 362,
#  'love_dragonss': 1077,
#  'god': 809,
#  '3rd': 42,
#  'fuel': 782,
#  'soon': 1626,
#  'word': 1959,
#  'dm': 555,
#  'resolve': 1473,
#  'useless': 1872,
#  'bags': 216,
#  'returned': 1485,
#  'couple': 443,
#  'kind': 993,
#  'adding': 89,
#  'airways': 117,
#  'myself': 1192,
#  'price': 1383,
#  'wonderful': 1956,
#  'attendant': 190,
#  'lga': 1035,
#  'grand': 820,
#  'total': 1780,
#  'landing': 1008,
#  '16': 13,
#  'fleet': 720,
#  'fleek': 719,
#  'lol': 1061,
#  'wow': 1975,
#  'embarrassing': 606,
#  'platinum': 1348,
#  'happy': 848,
#  'thnx': 1748,
#  'spent': 1643,
#  'morning': 1176,
#  'support': 1687,
#  'want': 1897,
#  'taken': 1706,
#  'knew': 995,
#  '2x': 34,
#  'min': 1152,
#  'following': 749,
#  'horrible': 894,
#  'post': 1371,
#  'business': 283,
#  'page': 1289,
#  'true': 1807,
#  '100': 3,
#  'caused': 319,
#  'four': 762,
#  'landed': 1007,
#  'someone': 1622,
#  'leave': 1021,
#  'arrive': 170,
#  'before': 233,
#  'were': 1925,
#  'supposed': 1689,
#  'impressed': 929,
#  'row': 1501,
#  'missing': 1163,
#  'luggage': 1089,
#  'most': 1178,
#  'amazing': 130,
#  'bring': 269,
#  'pass': 1298,
#  'flyer': 742,
#  'every': 635,
#  'lot': 1072,
#  'issues': 964,
#  'worth': 1972,
#  'thru': 1755,
#  'direct': 534,
#  'miami': 1142,
#  'rebooked': 1435,
#  'tuesday': 1815,
#  'phones': 1327,
#  'coming': 385,
#  'plat': 1347,
#  'upgraded': 1860,
#  'fa': 666,
#  'said': 1517,
#  'mistake': 1164,
#  'rather': 1422,
#  'complain': 397,
#  'public': 1405,
#  'into': 956,
#  'cant': 304,
#  'didnt': 526,
#  'accept': 74,
#  'looking': 1067,
#  'award': 202,
#  'seats': 1537,
#  'assigned': 182,
#  'dropped': 578,
#  '2nd': 33,
#  'hasn': 852,
#  'anything': 151,
#  'neveragain': 1203,
#  '140': 10,
#  'characters': 338,
#  'hopefully': 891,
#  '11': 5,
#  'trouble': 1804,
#  'checking': 350,
#  'add': 87,
#  'find': 708,
#  'slept': 1606,
#  'haven': 856,
#  'ua': 1829,
#  'land': 1006,
#  'rebook': 1434,
#  'denver': 501,
#  'best': 238,
#  'arrived': 171,
#  'pretty': 1381,
#  'texas': 1728,
#  'boarded': 255,
#  'fingers': 711,
#  'crossed': 455,
#  'options': 1264,
#  'tel': 1720,
#  'knows': 998,
#  'week': 1918,
#  'cheap': 345,
#  'couldn': 437,
#  'run': 1510,
#  'took': 1778,
#  'level': 1034,
#  'regarding': 1448,
#  'representative': 1462,
#  'disconnected': 546,
#  'really': 1431,
#  '45': 47,
#  'counting': 441,
#  'cares': 309,
#  'extra': 664,
#  'nights': 1212,
#  'hotels': 898,
#  'once': 1255,
#  'heard': 864,
#  'saying': 1526,
#  'seriously': 1554,
#  'philly': 1322,
#  'man': 1102,
#  'uk': 1832,
#  'charging': 342,
#  'biz': 249,
#  '70': 57,
#  'human': 910,
#  'letter': 1032,
#  'read': 1427,
#  'cust': 464,
#  'fi': 698,
#  'update': 1855,
#  'another': 143,
#  'crews': 453,
#  'surprised': 1692,
#  'guarantee': 826,
#  'literally': 1050,
#  'london': 1062,
#  'fyi': 790,
#  '1k': 18,
#  'unfriendlyskies': 1843,
#  'everything': 637,
#  'industry': 942,
#  'doing': 562,
#  'admirals': 93,
#  'news': 1206,
#  'wasted': 1904,
#  'fee': 689,
#  'badcustomerservice': 212,
#  'don': 565,
#  'de': 483,
#  'ice': 917,
#  '60': 54,
#  'warm': 1900,
#  'safe': 1514,
#  'taking': 1709,
#  'pilot': 1333,
#  'maintenance': 1095,
#  'atlanta': 188,
#  'she': 1567,
#  'hey': 875,
#  'follow': 747,
#  'volume': 1888,
#  'high': 877,
#  'apologies': 155,
#  'continue': 428,
#  'contacting': 427,
#  'reservations': 1471,
#  'assistance': 185,
#  'answer': 144,
#  'upgrade': 1859,
#  'start': 1654,
#  'cc': 322,
#  'these': 1740,
#  'usairwaysfail': 1867,
#  'global': 807,
#  'lounge': 1074,
#  'hanging': 842,
#  'almost': 122,
#  'responded': 1477,
#  'nor': 1219,
#  'tix': 1767,
#  'ago': 105,
#  'cheaper': 346,
#  '1st': 19,
#  'helping': 872,
#  'since': 1589,
#  'poor': 1363,
#  'customerservice': 467,
#  'plans': 1346,
#  'computer': 403,
#  'aren': 167,
#  'keep': 984,
#  'less': 1028,
#  'driving': 576,
#  'lack': 1002,
#  'fixed': 717,
#  'freezing': 767,
#  'return': 1484,
#  'nice': 1209,
#  'usual': 1874,
#  'suitcase': 1683,
#  'clean': 364,
#  'bna': 253,
#  'stranded': 1673,
#  'hoping': 892,
#  'glad': 806,
#  'listening': 1049,
#  'both': 263,
#  'legs': 1027,
#  'damaged': 475,
#  'expensive': 654,
#  'currently': 463,
#  'crying': 456,
#  'ski': 1600,
#  'schedule': 1528,
#  'turns': 1819,
#  'answered': 145,
#  'usair': 1865,
#  'saved': 1523,
#  'counter': 440,
#  'come': 383,
#  'flyfi': 744,
#  'seattle': 1538,
#  'cross': 454,
#  'country': 442,
#  'close': 368,
#  'eat': 595,
#  'tpa': 1784,
#  'cnn': 375,
#  'jfk': 977,
#  'doors': 569,
#  'ones': 1257,
#  'fill': 704,
#  'hope': 890,
#  'nyc': 1236,
#  'boston': 262,
#  'snow': 1614,
#  'storm': 1670,
#  'airports': 116,
#  'family': 677,
#  'each': 585,
#  'year': 1984,
#  '65': 56,
#  '22': 24,
#  'early': 587,
#  'request': 1464,
#  'badservice': 213,
#  'lies': 1038,
#  'away': 204,
#  'shuttle': 1582,
#  'excited': 646,
#  'plus': 1355,
#  'epicfail': 621,
#  'sent': 1552,
#  'him': 879,
#  'kiosks': 994,
#  'weren': 1926,
#  'damn': 476,
#  'bus': 281,
#  'deal': 485,
#  'share': 1565,
#  'responding': 1478,
#  'forward': 760,
#  'drive': 575,
#  'office': 1244,
#  'file': 702,
#  '10': 2,
#  '20': 20,
#  'attitude': 193,
#  'kudos': 1000,
#  'captain': 305,
#  'handling': 839,
#  'etc': 629,
#  'asap': 176,
#  'fault': 685,
#  'cool': 431,
#  'gave': 795,
#  'hr': 905,
#  '32': 38,
#  'few': 697,
#  'causing': 321,
#  'unreal': 1852,
#  'thing': 1742,
#  'consistent': 423,
#  'job': 979,
#  'tired': 1766,
#  'jet': 974,
#  'switching': 1699,
#  'anyway': 152,
#  'does': 558,
#  'trueblue': 1808,
#  'within': 1951,
#  'members': 1129,
#  'set': 1559,
#  'passengers': 1301,
#  'sleep': 1604,
#  'gold': 812,
#  'asked': 179,
#  'wont': 1958,
#  'transfer': 1789,
#  'yr': 1996,
#  'old': 1251,
#  'military': 1150,
#  'mom': 1169,
#  'emergency': 607,
#  'newark': 1205,
#  'under': 1838,
#  'compensated': 395,
#  'select': 1546,
#  'manage': 1103,
#  'months': 1174,
#  'emailed': 604,
#  'horrendous': 893,
#  'between': 241,
#  'management': 1105,
#  'funeral': 786,
#  'never': 1202,
#  'treated': 1798,
#  'poorly': 1364,
#  'ruined': 1507,
#  'changed': 334,
#  '200': 21,
#  'sick': 1583,
#  'living': 1053,
#  'count': 439,
#  'tarmac': 1714,
#  'rules': 1509,
#  'process': 1393,
#  'absolute': 70,
#  'disaster': 544,
#  'worries': 1967,
#  'doesnt': 560,
#  'allow': 119,
#  'wasn': 1902,
#  'allowed': 120,
#  'diff': 528,
#  'lines': 1045,
#  'door': 568,
#  'self': 1547,
#  'book': 258,
#  'huge': 909,
#  'iad': 915,
#  'daughter': 478,
#  'keeping': 985,
#  'mon': 1170,
#  'finally': 707,
#  'final': 706,
#  'destination': 516,
#  'play': 1349,
#  'video': 1883,
#  'relate': 1451,
#  'flightd': 725,
#  ...}

# %%
w[725, 0]
# Out:
# 0.31738484

# %%
# let's look at the weights for each word
# try it with different threshold values!
threshold = 2

print("Most positive words:")
word_weight_tuples = []
for word, index in word_index_map.items():
    weight = w[index, 0]
    if weight > threshold:
        word_weight_tuples.append((word, weight))

word_weight_tuples = sorted(word_weight_tuples, key=lambda x: -x[1])
for i in range(10):
  word, weight = word_weight_tuples[i]
  print(word, weight)
# Out:
# Most positive words:
# thank 9.59107
# thanks 9.496351
# great 7.996582
# awesome 6.861714
# love 6.8460655
# kudos 6.7973185
# excellent 6.6346374
# worries 6.5723934
# wonderful 6.4534116
# amazing 6.432428

# %%
print("Most negative words:")
word_weight_tuples = []
for word, index in word_index_map.items():
    weight = w[index, 0]
    if weight < -threshold:
        word_weight_tuples.append((word, weight))

word_weight_tuples = sorted(word_weight_tuples, key=lambda x: x[1])
for i in range(10):
  word, weight = word_weight_tuples[i]
  print(word, weight)
# Out:
# Most negative words:
# worst -8.776844
# paid -7.61737
# nothing -7.594361
# not -7.2236633
# disappointed -6.81938
# real -6.7692127
# rude -6.549523
# until -6.532847
# hours -6.5283875
# fail -6.512013
