# %% [markdown]
# [Source playlist](https://youtube.com/playlist?list=PLQVvvaa0QuDcjD5BAw2DxE6OF2tius3V3)

# %% [markdown]
# # First neuron

# %%
inputs = [1.2, 5.1, 2.1]
weights = [3.1, 2.1, 8.7]
bias = 3

# %%
output = inputs[0] * weights[0] + inputs[1] * weights[1] + inputs[2] * weights[2] + bias
print(output)

# output = 0
# for i in range(len(inputs)):
#     output += inputs[i] * weights[i]
# output = output + bias 
# print(output)
# Out:
# 35.7

# %% [markdown]
# # Coding a layer

# %% [markdown]
# These values are made up values for now.
# Later on the weights will be randomly initilaized and updated by backpropagation
#
# ![image.png](attachment:image.png)

# %%
inputs = [1, 2, 3]
weights = [0.2, 0.8, -0.5]
bias = 2

output = inputs[0] * weights[0] + inputs[1] * weights[1] + inputs[2] * weights[2] + bias
print(output)
# Out:
# 2.3

# %% [markdown]
# The inputs can be actual inputs, or outputs from previous neurons

# %% [markdown]
# Adding one more inputs, and thus weight.
# Notice that there's only one bias per neuron regardless of the number of inputs
#
# ![image.png](attachment:image.png)

# %%
inputs = [1, 2, 3, 2.5]
weights = [0.2, 0.8, -0.5, 1]
bias = 2

output = inputs[0] * weights[0] + inputs[1] * weights[1] + inputs[2] * weights[2] + inputs[3] * weights[3] + bias
print(output)
# Out:
# 4.8

# %% [markdown]
# #### Creating 3 nuerons with 4 inputs

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
inputs = [1, 2, 3, 2.5]

weights1 = [0.2, 0.8, -0.5, 1]
weights2 = [0.5, -0.91, 0.26, -0.5]
weights3 = [-0.26, -0.27, 0.17, 0.87]

bias1 = 2
bias2 = 3
bias3 = 0.5

# %%
output = [inputs[0] * weights1[0] + inputs[1] * weights1[1] + inputs[2] * weights1[2] + inputs[3] * weights1[3] + bias1,
          inputs[0] * weights2[0] + inputs[1] * weights2[1] + inputs[2] * weights2[2] + inputs[3] * weights2[3] + bias2,
          inputs[0] * weights3[0] + inputs[1] * weights3[1] + inputs[2] * weights3[2] + inputs[3] * weights3[3] + bias3,]
print(output)
# Out:
# [4.8, 1.21, 2.385]

# %% [markdown]
# # The dot product

# %%
inputs = [1, 2, 3, 2.5]
# weights1 = [0.2, 0.8, -0.5, 1]
# weights2 = [0.5, -0.91, 0.26, -0.5]
# weights3 = [-0.26, -0.27, 0.17, 0.87]
weights = [[0.2, 0.8, -0.5, 1],
           [0.5, -0.91, 0.26, -0.5],
           [-0.26, -0.27, 0.17, 0.87]]
# bias1 = 2
# bias2 = 3
# bias3 = 0.5
biases = [2,3,0.5]

# %%
layer_outputs = [] #output of current layer
for neuron_weights, neuron_bias in zip(weights, biases):
    print(neuron_weights, neuron_bias)
# Out:
# [0.2, 0.8, -0.5, 1] 2
# [0.5, -0.91, 0.26, -0.5] 3
# [-0.26, -0.27, 0.17, 0.87] 0.5

# %%
layer_outputs = [] #output of current layer
for neuron_weights, neuron_bias in zip(weights, biases):
    neuron_output = 0 # output of a given neuron
    for n_input, weight in zip(inputs, neuron_weights):
        neuron_output += n_input * weight
    neuron_output += neuron_bias
    layer_outputs.append(neuron_output)
    
print(layer_outputs)
# Out:
# [4.8, 1.21, 2.385]

# %% [markdown]
# #### Shape

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Notice that an array has to be homologous i.e., at each dimension it has to be of the same size.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Tensors are an object that can be represented as an array.

# %%
# Remember that the dot product of two vectors is a scalar

import numpy as np

inputs = [1, 2, 3, 2.5]
weights = [0.2, 0.8, -0.5, 1]
bias = 2

# %%
output = np.dot(weights, inputs) + bias
print(output)
# Out:
# 4.8

# %%
inputs = [1, 2, 3, 2.5]
weights = [[0.2, 0.8, -0.5, 1],
           [0.5, -0.91, 0.26, -0.5],
           [-0.26, -0.27, 0.17, 0.87]]
biases = [2,3,0.5]

# %%
ouput = np.dot(weights, inputs) + biases
print(output)
# Out:
# [4.8 5.8 3.3]

# %% [markdown]
# How it works:
#
#
# ![image.png](attachment:image.png)
